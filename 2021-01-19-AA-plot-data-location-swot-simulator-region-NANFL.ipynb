# %%
import xarray as xr
import numpy as np
import glob
import os

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import cartopy
cartopy.config['pre_existing_data_dir']  = '/home/ad/alberta/git/cartopy_data' 
import matplotlib
matplotlib.rcParams.update({'font.size': 22})

# %%
latminN=30
latmaxN=40
lonminN=-55
lonmaxN=-40

# %%
dir='/work/ALT/odatis/eNATL60/alberta/SWOT-sim/eNATL60-BLB002/'

region='NANFL'
tdir=dir+region+'/'

fig=plt.figure(figsize=(20,15))
ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
#ax = fig.add_subplot(111,projection=ccrs.Orthographic(central_longitude=-30,
#                                                        central_latitude=35))
ax.set_extent((-60, -35, 27, 50))
ax.coastlines(resolution="10m")
gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                          alpha=0.5)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
ax.tick_params('both',labelsize=22)

ax.plot([lonminN, lonminN], [latminN, latmaxN],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonmaxN, lonmaxN], [latminN, latmaxN],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonminN, lonmaxN], [latminN, latminN],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonminN, lonmaxN], [latmaxN, latmaxN],color='black',linewidth=3,transform=ccrs.PlateCarree())    

tdirf=tdir+'calval_phase/karin'
files=glob.glob(tdirf+'/*nc')
lat_all=[]
lon_all=[]
for f in np.arange(len(files)):
    f
    ds=xr.open_dataset(files[f])
    lat = ds['latitude'].values;
    lon = ds['longitude'].values;
    lonb=xr.where(lon>180,lon-360,lon)
    lat_all.append(lat)
    lon_all.append(lonb)
plt.scatter(np.concatenate(lon_all,axis=None),
            np.concatenate(lat_all,axis=None), c='palegreen',
            label='calval_phase-karin', linewidth=0, s=18,
            transform=ccrs.PlateCarree(),zorder=1);

tdirf=tdir+'calval_phase/nadir'
files=glob.glob(tdirf+'/*nc')
lat_all=[]
lon_all=[]
for f in np.arange(len(files)):
    f
    ds=xr.open_dataset(files[f])
    lat = ds['latitude_nadir'].values;
    lon = ds['longitude_nadir'].values;
    lonb=xr.where(lon>180,lon-360,lon)
    lat_all.append(lat)
    lon_all.append(lonb)
plt.scatter(np.concatenate(lon_all,axis=None),
            np.concatenate(lat_all,axis=None), 
            c='seagreen',label='calval_phase-nadir', 
            linewidth=0, s=18,transform=ccrs.PlateCarree(),zorder=2);
ax.legend();
plt.savefig('tracks_swot-sim_calval_NANFL.png')

# %%
dir='/work/ALT/odatis/eNATL60/alberta/SWOT-sim/eNATL60-BLB002/'

region='NANFL'
tdir=dir+region+'/'

fig=plt.figure(figsize=(20,15))
ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
#ax = fig.add_subplot(111,projection=ccrs.Orthographic(central_longitude=-30,
#                                                        central_latitude=35))
ax.set_extent((-60, -35, 27, 50))
ax.coastlines(resolution="10m")
gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                          alpha=0.5)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
ax.tick_params('both',labelsize=22)

ax.plot([lonminN, lonminN], [latminN, latmaxN],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonmaxN, lonmaxN], [latminN, latmaxN],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonminN, lonmaxN], [latminN, latminN],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonminN, lonmaxN], [latmaxN, latmaxN],color='black',linewidth=3,transform=ccrs.PlateCarree())    

tdirf=tdir+'science_phase/karin'
files=glob.glob(tdirf+'/*nc')
lat_all=[]
lon_all=[]
for f in np.arange(len(files)):
    ds=xr.open_dataset(files[f])
    lat = ds['latitude'].values;
    lon = ds['longitude'].values;
    lonb=xr.where(lon>180,lon-360,lon)
    lat_all.append(lat)
    lon_all.append(lonb)
plt.scatter(np.concatenate(lon_all,axis=None),
            np.concatenate(lat_all,axis=None), c='palegreen',
            label='science_phase-karin', linewidth=0, s=18,
            transform=ccrs.PlateCarree(),zorder=1);

tdirf=tdir+'science_phase/nadir'
files=glob.glob(tdirf+'/*nc')
lat_all=[]
lon_all=[]
for f in np.arange(len(files)):
    ds=xr.open_dataset(files[f])
    lat = ds['latitude_nadir'].values;
    lon = ds['longitude_nadir'].values;
    lonb=xr.where(lon>180,lon-360,lon)
    lat_all.append(lat)
    lon_all.append(lonb)
plt.scatter(np.concatenate(lon_all,axis=None),
            np.concatenate(lat_all,axis=None), 
            c='seagreen',label='science_phase-nadir', 
            linewidth=0, s=18,transform=ccrs.PlateCarree(),zorder=2);
ax.legend();
plt.savefig('tracks_swot-sim_science_NANFL.png')
