# %%
import xarray as xr
import numpy as np
import glob

# %%
phase='calval_phase' # calval_phase or science_phase
simu='eNATL60-BLB002' # or eNATL60-BLBT02
data='karin' # or nadir

# %% [raw]
# #parameters for the region to consider
# reg='MEDWEST'
# latmin=35.1
# latmax=44.4
# lonmin=-5.7
# lonmax=9.6

# %%
#parameters for the region to consider
reg='NANFL'
latmin=30
latmax=40
lonmin=-55+360
lonmax=-40+360

# %%
tdir='/work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_'+phase+'/'+simu+'-SSH-1h/'+data
files=glob.glob(tdir+'/*/*nc')

# %%
def check_data_region(file,latmin,latmax,lonmin,lonmax):
    ds=xr.open_dataset(file)
    latfile=ds.latitude
    lonfile=ds.longitude
    ind_region=np.where((latfile < latmax) & (latfile > latmin) & 
        (lonfile < lonmax) & (lonfile > lonmin))
    if len(ind_region[0]) > 0:
 #       print(file+' has data relevant to the region selected')
        check=1
    else:
        check=0
    return check,ind_region

# %%
def check_data_nonan(file,ind_region):
    ds=xr.open_dataset(file)
    latfile=ds.latitude
    lonfile=ds.longitude
    ssh=ds.ssh_karin    
    numlines_region=ind_region[0]
    numlines_region_unique=np.unique(numlines_region)
    for k in np.arange(len(numlines_region_unique)):
        isdata=np.where(np.isnan(ssh[numlines_region_unique[k],:])==False)
        if len(isdata[0])>0:
            print(file+' has non NaN data')
            check=1
        else:
            check=0
        return check,isdata

# %%
for f in np.arange(len(files)):
    file=files[f]
    check, ind_region = check_data_region(file,latmin,latmax,lonmin,lonmax)
    if check == 1:
        check2,isdata = check_data_nonan(file,ind_region)
# Out:
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_341_011_20100603T042122_20100603T051228_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_374_024_20100706T101600_20100706T110705_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_277_011_20100331T142145_20100331T151251_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_213_024_20100127T112622_20100127T121727_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_398_024_20100730T063051_20100730T072157_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_195_011_20100109T031101_20100109T040206_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_204_024_20100118T125048_20100118T134153_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_305_024_20100428T210318_20100428T215423_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_249_024_20100304T054838_20100304T063944_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_317_024_20100510T191043_20100510T200149_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_356_011_20100618T020039_20100618T025145_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_320_024_20100513T184235_20100513T193340_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator
DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_264_011_20100318T162343_20100318T171448_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_198_024_20100112T134705_20100112T143810_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_201_011_20100115T021443_20100115T030549_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_235_024_20100218T075959_20100218T085104_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_321_011_20100514T072859_20100514T082005_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_271_011_20100325T151803_20100325T160908_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_190_011_20100104T035755_20100104T044901_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_363_011_20100625T005459_20100625T014604_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_365_011_20100627T003613_20100627T012719_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_357_024_20100619T125529_20100619T134634_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_363_024_20100625T115912_20100625T125017_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_381_024_20100713T091020_20100713T100125_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_248_011_20100302T185349_20100302T194454_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_187_024_20100101T153016_20100101T162122_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_281_024_20100405T004827_20100405T013932_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_330_011_20100523T060433_20100523T065539_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_352_024_20100614T134223_20100614T143328_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_306_011_20100429T094942_20100429T104048_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_calval_phase/eNATL60-BLB002-SSH-1h/karin/2010/SWOT_L2_LR_SSH_Basic_338_024_20100531T155343_20100531T164449_DG10_01.nc has non NaN data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6672e9b8136f> in <module>
#       1 for f in np.arange(len(files)):
#       2     file=files[f]
# ----> 3     check, ind_region = check_data_region(file,latmin,latmax,lonmin,lonmax)
#       4     if check == 1:
#       5         check2,isdata = check_data_nonan(file,ind_region)
#
# <ipython-input-10-54f5e351300c> in check_data_region(file, latmin, latmax, lonmin, lonmax)
#       4     lonfile=ds.longitude
#       5     ind_region=np.where((latfile < latmax) & (latfile > latmin) &
# ----> 6         (lonfile < lonmax) & (lonfile > lonmin))
#       7     if len(ind_region[0]) > 0:
#       8  #       print(file+' has data relevant to the region selected')
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/dataarray.py in func(self, other)
#    2912
#    2913             variable = (
# -> 2914                 f(self.variable, other_variable)
#    2915                 if not reflexive
#    2916                 else f(other_variable, self.variable)
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/variable.py in func(self, other)
#    2188             if isinstance(other, (xr.DataArray, xr.Dataset)):
#    2189                 return NotImplemented
# -> 2190             self_data, other_data, dims = _broadcast_compat_data(self, other)
#    2191             keep_attrs = _get_keep_attrs(default=False)
#    2192             attrs = self._attrs if keep_attrs else None
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/variable.py in _broadcast_compat_data(self, other)
#    2662     else:
#    2663         # rely on numpy broadcasting rules
# -> 2664         self_data = self.data
#    2665         other_data = other
#    2666         dims = self.dims
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/variable.py in data(self)
#     359             return self._data
#     360         else:
# --> 361             return self.values
#     362
#     363     @data.setter
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/variable.py in values(self)
#     510     def values(self):
#     511         """The variable's data as a numpy.ndarray"""
# --> 512         return _as_array_or_item(self._data)
#     513
#     514     @values.setter
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     272         data = data.get()
#     273     else:
# --> 274         data = np.asarray(data)
#     275     if data.ndim == 0:
#     276         if data.dtype.kind == "M":
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     691
#     692     def __array__(self, dtype=None):
# --> 693         self._ensure_cached()
#     694         return np.asarray(self.array, dtype=dtype)
#     695
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/indexing.py in _ensure_cached(self)
#     688     def _ensure_cached(self):
#     689         if not isinstance(self.array, NumpyIndexingAdapter):
# --> 690             self.array = NumpyIndexingAdapter(np.asarray(self.array))
#     691
#     692     def __array__(self, dtype=None):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     661
#     662     def __array__(self, dtype=None):
# --> 663         return np.asarray(self.array, dtype=dtype)
#     664
#     665     def __getitem__(self, key):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     566     def __array__(self, dtype=None):
#     567         array = as_indexable(self.array)
# --> 568         return np.asarray(array[self.key], dtype=None)
#     569
#     570     def transpose(self, order):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      68
#      69     def __array__(self, dtype=None):
# ---> 70         return self.func(self.array)
#      71
#      72     def __repr__(self):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/coding/variables.py in _scale_offset_decoding(data, scale_factor, add_offset, dtype)
#     216
#     217 def _scale_offset_decoding(data, scale_factor, add_offset, dtype):
# --> 218     data = np.array(data, dtype=dtype, copy=True)
#     219     if scale_factor is not None:
#     220         data *= scale_factor
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      68
#      69     def __array__(self, dtype=None):
# ---> 70         return self.func(self.array)
#      71
#      72     def __repr__(self):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/coding/variables.py in _apply_mask(data, encoded_fill_values, decoded_fill_value, dtype)
#     136 ) -> np.ndarray:
#     137     """Mask all matching values in a NumPy arrays."""
# --> 138     data = np.asarray(data, dtype=dtype)
#     139     condition = False
#     140     for fv in encoded_fill_values:
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     566     def __array__(self, dtype=None):
#     567         array = as_indexable(self.array)
# --> 568         return np.asarray(array[self.key], dtype=None)
#     569
#     570     def transpose(self, order):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in __getitem__(self, key)
#      70
#      71     def __getitem__(self, key):
# ---> 72         return indexing.explicit_indexing_adapter(
#      73             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#      74         )
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     851     """
#     852     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 853     result = raw_indexing_method(raw_key.tuple)
#     854     if numpy_indices.tuple:
#     855         # index the loaded np.ndarray
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in _getitem(self, key)
#      83             with self.datastore.lock:
#      84                 original_array = self.get_array(needs_lock=False)
# ---> 85                 array = getitem(original_array, key)
#      86         except IndexError:
#      87             # Catch IndexError in netCDF4 and return a more informative
#
# KeyboardInterrupt:
