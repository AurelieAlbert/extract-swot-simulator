# %%
import xarray as xr
import numpy as np
import glob
import os

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import cartopy
cartopy.config['pre_existing_data_dir']  = '/home/ad/alberta/git/cartopy_data' 
import matplotlib
matplotlib.rcParams.update({'font.size': 22})

# %%
latminM=35.1
latmaxM=44.4
lonminM=-5.7
lonmaxM=9.6

# %%
dir='/work/ALT/odatis/eNATL60/alberta/SWOT-sim/eNATL60-BLB002/'

region='MEDWEST'
tdir=dir+region+'/'

fig=plt.figure(figsize=(20,15))
ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
#ax = fig.add_subplot(111,projection=ccrs.Orthographic(central_longitude=-30,
#                                                        central_latitude=35))
ax.set_extent((-7.5, 10, 35, 45))
ax.coastlines(resolution="10m")
gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                          alpha=0.5)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
ax.tick_params('both',labelsize=22)

ax.plot([lonminM, lonminM], [latminM, latmaxM],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonmaxM, lonmaxM], [latminM, latmaxM],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonminM, lonmaxM], [latminM, latminM],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonminM, lonmaxM], [latmaxM, latmaxM],color='black',linewidth=3,transform=ccrs.PlateCarree())    

tdirf=tdir+'calval_phase/karin'
files=glob.glob(tdirf+'/*nc')
lat_all=[]
lon_all=[]
for f in np.arange(len(files)):
    ds=xr.open_dataset(files[f])
    lat = ds['latitude'].values;
    lon = ds['longitude'].values;
    lonb=xr.where(lon>180,lon-360,lon)
    lat_all.append(lat)
    lon_all.append(lonb)
plt.scatter(np.concatenate(lon_all,axis=None),
            np.concatenate(lat_all,axis=None), c='turquoise',
            label='calval_phase-karin', linewidth=0, s=18,
            transform=ccrs.PlateCarree(),zorder=1);

tdirf=tdir+'calval_phase/nadir'
files=glob.glob(tdirf+'/*nc')
lat_all=[]
lon_all=[]
for f in np.arange(len(files)):
    ds=xr.open_dataset(files[f])
    lat = ds['latitude_nadir'].values;
    lon = ds['longitude_nadir'].values;
    lonb=xr.where(lon>180,lon-360,lon)
    lat_all.append(lat)
    lon_all.append(lonb)
plt.scatter(np.concatenate(lon_all,axis=None),
            np.concatenate(lat_all,axis=None), 
            c='royalblue',label='calval_phase-nadir', 
            linewidth=0, s=18,transform=ccrs.PlateCarree(),zorder=2);
ax.legend();
plt.savefig('tracks_swot-sim_calval_MEDWEST.png')

# %%
dir='/work/ALT/odatis/eNATL60/alberta/SWOT-sim/eNATL60-BLB002/'

region='MEDWEST'
tdir=dir+region+'/'

fig=plt.figure(figsize=(20,15))
ax = plt.subplot(111,projection=ccrs.PlateCarree(central_longitude=0))
#ax = fig.add_subplot(111,projection=ccrs.Orthographic(central_longitude=-30,
#                                                        central_latitude=35))
ax.set_extent((-7.5, 10, 35, 45))
ax.coastlines(resolution="10m")
gl = ax.gridlines(draw_labels=True, linestyle=':', color='black',
                          alpha=0.5)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
ax.tick_params('both',labelsize=22)

ax.plot([lonminM, lonminM], [latminM, latmaxM],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonmaxM, lonmaxM], [latminM, latmaxM],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonminM, lonmaxM], [latminM, latminM],color='black',linewidth=3,transform=ccrs.PlateCarree())
ax.plot([lonminM, lonmaxM], [latmaxM, latmaxM],color='black',linewidth=3,transform=ccrs.PlateCarree())    

tdirf=tdir+'science_phase/karin'
files=glob.glob(tdirf+'/*nc')
lat_all=[]
lon_all=[]
for f in np.arange(len(files)):
    ds=xr.open_dataset(files[f])
    lat = ds['latitude'].values;
    lon = ds['longitude'].values;
    lonb=xr.where(lon>180,lon-360,lon)
    lat_all.append(lat)
    lon_all.append(lonb)
plt.scatter(np.concatenate(lon_all,axis=None),
            np.concatenate(lat_all,axis=None), c='turquoise',
            label='science_phase-karin', linewidth=0, s=18,
            transform=ccrs.PlateCarree(),zorder=1);

tdirf=tdir+'science_phase/nadir'
files=glob.glob(tdirf+'/*nc')
lat_all=[]
lon_all=[]
for f in np.arange(len(files)):
    ds=xr.open_dataset(files[f])
    lat = ds['latitude_nadir'].values;
    lon = ds['longitude_nadir'].values;
    lonb=xr.where(lon>180,lon-360,lon)
    lat_all.append(lat)
    lon_all.append(lonb)
plt.scatter(np.concatenate(lon_all,axis=None),
            np.concatenate(lat_all,axis=None), 
            c='royalblue',label='science_phase-nadir', 
            linewidth=0, s=18,transform=ccrs.PlateCarree(),zorder=2);
ax.legend();
plt.savefig('tracks_swot-sim_science_MEDWEST.png')
# Out:
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:479: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   return matplotlib.axes.Axes.draw(self, renderer=renderer, **kwargs)
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
