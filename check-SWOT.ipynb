# %%
import xarray as xr
import numpy as np

# %%
ds1=xr.open_dataset('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_130_001_20091105T044950_20091105T054055_DG10_01.nc')

# %%
ds2=xr.open_dataset('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_130_002_20091105T054056_20091105T063201_DG10_01.nc')

# %%
# !ls /work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_130_002_20091105T054056_20091105T063201_DG10_01.nc
# Out:
# /work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_130_002_20091105T054056_20091105T063201_DG10_01.nc

# %%
ds1_2=xr.concat([ds1,ds2],dim='num_lines')

# %%
ds1_2.ssh_karin.plot()

# %%
k3=str(k).zfill(3)
file=glob.glob('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_130_'+str(k3)+'*.nc')
dstot=xr.open_dataset(file[0])

# %%
file=glob.glob('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_130_001*.nc')
dstot=xr.open_dataset(file[0])

# %%
file=glob.glob('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_130_001*.nc')
dstot=xr.open_dataset(file[0])
for k in np.arange(2,28):
    k3=str(k).zfill(3)
    file=glob.glob('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_130_'+str(k3)+'*.nc')
    ds1=xr.open_dataset(file[0])
    dstot=xr.concat([dstot,ds1],dim='num_lines')

# %%
dstot
# Out:
# <xarray.Dataset>
# Dimensions:                (num_lines: 266414, num_pixels: 71)
# Coordinates:
#     latitude               (num_lines, num_pixels) float64 -78.29 ... 78.29
#     longitude              (num_lines, num_pixels) float64 350.3 350.3 ... 183.2
# Dimensions without coordinates: num_lines, num_pixels
# Data variables:
#     time                   (num_lines) datetime64[ns] 2009-11-05T04:49:50.105...
#     ssh_karin              (num_lines, num_pixels) float64 nan nan ... nan nan
#     err_roll               (num_lines, num_pixels) float64 nan nan ... nan nan
#     err_timing             (num_lines, num_pixels) float64 nan nan ... nan nan
#     err_karin              (num_lines, num_pixels) float64 nan nan ... nan nan
#     ssh_karin_true         (num_lines, num_pixels) float64 nan nan ... nan nan
#     err_phase              (num_lines, num_pixels) float64 nan nan ... nan nan
#     err_wet_troposphere    (num_lines, num_pixels) float64 nan nan ... nan nan
# ...

# %%
dstot.ssh_karin
# Out:
# <xarray.DataArray 'ssh_karin' (num_lines: 266414, num_pixels: 71)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
# Coordinates:
#     latitude   (num_lines, num_pixels) float64 -78.29 -78.27 ... 78.27 78.29
#     longitude  (num_lines, num_pixels) float64 350.3 350.3 350.3 ... 183.2 183.2
# Dimensions without coordinates: num_lines, num_pixels
# Attributes:
#     long_name:      sea surface height
#     standard_name:  sea surface height above reference ellipsoid
#     units:          m
#     valid_min:      -15000000
#     valid_max:      150000000
#     comment:        Fully corrected sea surface height measured by KaRIn. The...

# %%
dstot.ssh_karin[46000:46600].plot()

# %%
dstot.longitude[46300,:]
# Out:
# <xarray.DataArray 'longitude' (num_pixels: 71)>
# array([29.113402, 29.092292, 29.071179, 29.050065, 29.028949, 29.007831,
#        28.986711, 28.96559 , 28.944466, 28.923341, 28.902214, 28.881085,
#        28.859955, 28.838822, 28.817688, 28.796552, 28.775414, 28.754275,
#        28.733133, 28.71199 , 28.690845, 28.669698, 28.648549, 28.627399,
#        28.606247, 28.585092, 28.563937, 28.542779, 28.52162 , 28.500458,
#        28.479295, 28.458131, 28.436964, 28.415796, 28.394625, 28.373454,
#        28.35228 , 28.331104, 28.309927, 28.288748, 28.267567, 28.246385,
#        28.2252  , 28.204014, 28.182826, 28.161637, 28.140445, 28.119252,
#        28.098057, 28.07686 , 28.055662, 28.034462, 28.01326 , 27.992056,
#        27.970851, 27.949643, 27.928434, 27.907224, 27.886011, 27.864797,
#        27.843581, 27.822363, 27.801144, 27.779923, 27.7587  , 27.737475,
#        27.716249, 27.69502 , 27.673791, 27.652559, 27.631326])
# Coordinates:
# ...

# %%
dstot.latitude[46300,:]
# Out:
# <xarray.DataArray 'latitude' (num_pixels: 71)>
# array([33.546573, 33.55031 , 33.554043, 33.557773, 33.561499, 33.565221,
#        33.56894 , 33.572655, 33.576367, 33.580075, 33.583779, 33.58748 ,
#        33.591177, 33.594871, 33.598561, 33.602248, 33.605931, 33.60961 ,
#        33.613286, 33.616958, 33.620626, 33.624291, 33.627953, 33.63161 ,
#        33.635264, 33.638915, 33.642562, 33.646205, 33.649845, 33.653481,
#        33.657114, 33.660743, 33.664368, 33.66799 , 33.671608, 33.675222,
#        33.678833, 33.68244 , 33.686044, 33.689644, 33.69324 , 33.696833,
#        33.700422, 33.704008, 33.70759 , 33.711168, 33.714743, 33.718314,
#        33.721881, 33.725445, 33.729006, 33.732562, 33.736115, 33.739665,
#        33.74321 , 33.746752, 33.750291, 33.753826, 33.757357, 33.760885,
#        33.764409, 33.767929, 33.771446, 33.774959, 33.778468, 33.781974,
#        33.785476, 33.788975, 33.79247 , 33.795961, 33.799449])
# Coordinates:
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(dstot.longitude[46000:46600], dstot.latitude[46000:46600],c=dstot.ssh_karin[46000:46600])

# %%
ds=xr.open_mfdataset('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_081*nc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d4de49869d1b> in <module>
# ----> 1 ds=xr.open_mfdataset('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_081*nc')
#
# /softs/rh7/conda-envs/pangeo_202010/lib/python3.8/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, combine, autoclose, parallel, join, attrs_file, **kwargs)
#     944             # Redo ordering from coordinates, ignoring how they were ordered
#     945             # previously
# --> 946             combined = combine_by_coords(
#     947                 datasets,
#     948                 compat=compat,
#
# ...

# %%
ds=xr.open_mfdataset('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/*nc',concat_dim='num_lines')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bd53fd2ca8b5> in <module>
# ----> 1 ds=xr.open_mfdataset('/work/ALT/swot/aval/wisa/tmp/swot_simulator_calval_phase/eNATL60-BLBT02-SSH-1h/karin/2009/*nc',concat_dim='num_lines')
#
# /softs/rh7/conda-envs/pangeo_202010/lib/python3.8/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, combine, autoclose, parallel, join, attrs_file, **kwargs)
#     916         getattr_ = getattr
#     917
# --> 918     datasets = [open_(p, **open_kwargs) for p in paths]
#     919     file_objs = [getattr_(ds, "_file_obj") for ds in datasets]
#     920     if preprocess is not None:
#
# /softs/rh7/conda-envs/pangeo_202010/lib/python3.8/site-packages/xarray/backends/api.py in <listcomp>(.0)
#     916         getattr_ = getattr
#     917
# ...
