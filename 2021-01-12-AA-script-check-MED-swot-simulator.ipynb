# %%
import xarray as xr
import numpy as np
import glob

# %%
phase='science_phase' # calval_phase or science_phase
simu='eNATL60-BLB002' # or eNATL60-BLBT02
data='karin' # or nadir

# %%
#parameters for the region to consider
reg='MED'
latmin=30
latmax=45.5
lonmin=-5.7
lonmax=38

# %%
tdir='/work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_'+phase+'/'+simu+'-SSH-1h/'+data
files=glob.glob(tdir+'/2009/*nc')

# %%
def check_data_region(file,latmin,latmax,lonmin,lonmax):
    ds=xr.open_dataset(file)
    latfile=ds.latitude
    lonfile=ds.longitude
    ind_region=np.where((latfile < latmax) & (latfile > latmin) & 
        (lonfile < lonmax) & (lonfile > lonmin))
    if len(ind_region[0]) > 0:
 #       print(file+' has data relevant to the region selected')
        check=1
    else:
        check=0
    return check,ind_region

# %%
def check_data_nonan(file,ind_region):
    ds=xr.open_dataset(file)
    latfile=ds.latitude
    lonfile=ds.longitude
    ssh=ds.ssh_karin    
    numlines_region=ind_region[0]
    numlines_region_unique=np.unique(numlines_region)
    for k in np.arange(len(numlines_region_unique)):
        isdata=np.where(np.isnan(ssh[numlines_region_unique[k],:])==False)
        if len(isdata[0])>0:
            print(file+' has non NaN data')
            check=1
        else:
            check=0
        return check,isdata

# %%
for phase in ['science_phase','calval_phase']:
    print('cheking phase '+phase)
    for f in np.arange(len(files)):
        file=files[f]
        check, ind_region = check_data_region(file,latmin,latmax,lonmin,lonmax)
        if check == 1:
            check2,isdata = check_data_nonan(file,ind_region)
# Out:
# cheking phase science_phase
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_007_339_20091114T071842_20091114T081009_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_002_488_20090807T071933_20090807T081100_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_006_339_20091024T103346_20091024T112512_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_001_367_20090713T024933_20090713T034059_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_005_046_20090923T023454_20090923T032620_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_008_488_20091210T114914_20091210T124040_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_002_460_20090806T071903_20090806T081029_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_001_516_20090718T103507_20090718T112634_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_007_018_20091102T200416_20091102T205542_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_005_434_20091006T231615_20091007T000742_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_004_339_20090912T170352_20090912T175519_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_003_488_20090828T040430_20090828T045557_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_004_182_20090907T022642_20090907T031809_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator
DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_008_544_20091212T115015_20091212T124141_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_002_367_20090802T233429_20090803T002556_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_007_488_20091119T150417_20091119T155543_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_004_488_20090918T004927_20090918T014053_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_003_367_20090823T201926_20090823T211052_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_005_339_20091003T134849_20091003T144015_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_005_018_20090922T023423_20090922T032549_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_001_154_20090705T121122_20090705T130248_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_009_367_20091227T004906_20091227T014033_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_009_488_20091231T083411_20091231T092537_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_009_434_20091229T101602_20091229T110729_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_007_046_20091103T200447_20091103T205613_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_007_367_20091115T071913_20091115T081039_DG10_01.nc has non NaN data
# /work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_002_339_20090801T233359_20090802T002525_DG10_01.nc has non NaN data
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/work/ALT/swot/aval/wisa/tmp/inland_cleaning/swot_simulator_science_phase/eNATL60-BLB002-SSH-1h/karin/2009/SWOT_L2_LR_SSH_Basic_002_257_20090730T011520_20090730T020646_DG10_01.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d736c8997724> in <module>
#       3     for f in np.arange(len(files)):
#       4         file=files[f]
# ----> 5         check, ind_region = check_data_region(file,latmin,latmax,lonmin,lonmax)
#       6         if check == 1:
#       7             check2,isdata = check_data_nonan(file,ind_region)
#
# <ipython-input-5-54f5e351300c> in check_data_region(file, latmin, latmax, lonmin, lonmax)
#       1 def check_data_region(file,latmin,latmax,lonmin,lonmax):
# ----> 2     ds=xr.open_dataset(file)
#       3     latfile=ds.latitude
#       4     lonfile=ds.longitude
#       5     ind_region=np.where((latfile < latmax) & (latfile > latmin) &
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     570
#     571         opener = _get_backend_cls(engine)
# --> 572         store = opener(filename_or_obj, **extra_kwargs, **backend_kwargs)
#     573
#     574     with close_on_error(store):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     362             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     363         )
# --> 364         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     365
#     366     def _acquire(self, needs_lock=True):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     312         self._group = group
#     313         self._mode = mode
# --> 314         self.format = self.ds.data_model
#     315         self._filename = self.ds.filepath()
#     316         self.is_remote = is_remote_uri(self._filename)
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     371     @property
#     372     def ds(self):
# --> 373         return self._acquire()
#     374
#     375     def open_store_variable(self, name, var):
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     365
#     366     def _acquire(self, needs_lock=True):
# --> 367         with self._manager.acquire_context(needs_lock) as root:
#     368             ds = _nc4_require_group(root, self._group, self._mode)
#     369         return ds
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._get_vars()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable.__init__()
#
# /softs/rh7/conda-envs/pangeo_202012/lib/python3.8/site-packages/netCDF4/utils.py in _find_dim(grp, dimname)
#      39     return [A[i] for i in sorted(range(len(A)), key=B.__getitem__)]
#      40
# ---> 41 def _find_dim(grp, dimname):
#      42     # find Dimension instance given group and name.
#      43     # look in current group, and parents.
#
# KeyboardInterrupt:
